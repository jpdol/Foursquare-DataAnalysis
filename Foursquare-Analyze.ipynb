# %% [markdown]
# # Análise de Dados de Manaus com Foursquare
#
# Este Trabalho tem o objetivo de analisar dados da cidade de Manaus-AM obtidos na rede social Foursquare nos anos de 2015,2016 e 2017, e assim responder as seguintes questões:
# - Quantos Check-ins ocorreram nesse período?
# - Em quantos locais distintos foram realizados esses Check-ins?
# - Como estão distribuídos esses Check-ins pela cidade?
# - A quais categorias esses Check-ins pertencem?
# - Quais são as Subcategorias
# - Quais os locais mais bem avaliados da cidade?
# - Quais são os lugares mais frequenados de Manaus?

# %% [markdown]
# ## Bibliotecas

# %%
import gmplot #google maps plot
import pandas as pd
import matplotlib.pyplot as plt #ferramenta para plot

% matplotlib inline

# %% [markdown]
# ## Carregando bases de Dados

# %%
mao_2015_df = pd.read_csv('Data/Foursquare_MAO_MAR_2015', encoding = 'utf-8')
mao_2016_df = pd.read_csv('Data/Foursquare_MAO_MAR_2016', encoding = 'utf-8')
mao_2017_df = pd.read_csv('Data/Foursquare_MAO_MAR_2017', encoding = 'utf-8')

# %%
frames = [mao_2015_df, mao_2016_df, mao_2017_df]
mao_df = pd.concat(frames) #dataset com os anos de 2015, 2016 e 2017
mao_df
# Out:
#       CREATED AT  TIME ZONE OFFSET USER GENDER                  VENUE ID  \
# 0     1425168058              -240      female  4b535772f964a520249827e3
# 1     1425168234              -240      female  54b06ea9498e668872a79d7b
# 2     1425168242              -240      female  54580412498e633d7f5188af
# 3     1425168257              -240        male  4ecc3b8161af1f8ac32f354a
# 4     1425168263              -240      female  4b535772f964a520249827e3
# 5     1425168344              -240        male  52bba79e498e5d69657ae557
# 6     1425168453              -240        none  53658b00498ee61c4d6f5ad5
# 7     1425168607              -240      female  4c2d2f35e307d13ad7710dda
# 8     1425168697              -240      female  4bb7be58314e95211ca2479d
# 9     1425168876              -240        male  501c154ce4b01e9e71ba350e
# 10    1425168921              -240        male  511845cbe4b01271856cda47
# 11    1425169091              -240        male  4eb5ece4775b544c27885ebe
# 12    1425169138              -240      female  4c94113f38dd8cfa0cbfc562
# 13    1425169220              -240      female  5334d143498e2f5d62956330
# 14    1425169299              -240      female  514fa86ee4b0a1834b768adc
# 15    1425169299              -240        male  4f175676e4b0ba019490640a
# 16    1425169526              -240      female  4f9b4fc8e4b02343c7aaa4e4
# 17    1425169545              -240      female  53caf2c3498edc8c0e4aa44a
# 18    1425169572              -240        male  4ea4f8e98b81a02f8aa555d2
# 19    1425169633              -240      female  510bab01e4b0607cdd50cc94
# 20    1425169678              -240        male  4e98d2d89a52ceeb87edc8bc
# 21    1425169711              -240      female  4ef136595c5cfe0cf60d20af
# 22    1425169774              -240        male  4f25ddb5e4b0b2f990ecaf24
# 23    1425169844              -240        male  515f823ae4b0a6b1b1245c26
# 24    1425169892              -240      female  548b087f498ecccac94e5629
# 25    1425169977              -240      female  4f21e37fe4b0717a65d20303
# 26    1425170218              -240      female  4ea422facc2102b34db480ab
# 27    1425170218              -240        male  4bb7be58314e95211ca2479d
# 28    1425170256              -240        male  5044b5f2e4b0f30043014d14
# 29    1425170442              -240      female  53584318498e575268944d59
# ...          ...               ...         ...                       ...
# 9084  1491000418              -240        male  4b48d003f964a520245826e3
# 9085  1491000489              -240        male  574ed253498e1965835e39a3
# 9086  1491000491              -240        male  512d2298e4b05d64acaf6833
# 9087  1491000569              -240        male  4bd8944af645c9b69058a8e0
# 9088  1491000883              -240      female  4e77d3d21495f00a41f5a8c3
# 9089  1491001355              -240        male  4e1f99f6483b041af1da3819
# 9090  1491001402              -240        none  57e9bbe6498e09dc165cedb6
# 9091  1491001850              -240      female  50f45ec3e4b04829681562b5
# 9092  1491002194              -240        male  5271083811d2b270f8802b69
# 9093  1491002209              -240        male  4fd5e1fae4b0052fbc85e894
# 9094  1491003325              -240      female  4fe11307e4b0aaff312aa68f
# 9095  1491003580              -240        male  55d4e2dd498e1d0088c0f81a
# 9096  1491002235              -240        male  4bb1e7b6f964a520b4a93ce3
# 9097  1491002236              -240      female  4ed8cd1f4901c8be1b8e631b
# 9098  1491002274              -240        male  4df7ec8ea809df9984e83d7a
# 9099  1491002326              -240        male  4d5c59f19c31b60c4fd7b3ee
# 9100  1491002851              -240        male  53f25452498e5267c3a74c28
# 9101  1491003021              -240      female  4b4778e2f964a520273326e3
# 9102  1491003036              -240      female  4e79250c62e1645552b04803
# 9103  1491003078              -240        male  507f3348e4b05f6a42aada14
# 9104  1491003292              -240        male  55c3ef5f498ee96787ef5bfb
# 9105  1491003343              -240        male  4b983bf7f964a520213635e3
# 9106  1491003488              -240        male  549182ab498e3b9a5cf7609d
# 9107  1491003784              -240      female  5823d3428c646e5a42fd8391
# 9108  1491003806              -240        male  58893fbb16f0006679f1110d
# 9109  1491003935              -240        male  4e74f5cf45ddd4323f862b3a
# 9110  1491004177              -240      female  4e6934c545dd0f430c1651dd
# 9111  1491004400              -240        male  4ee566977beb4f3b719c3d13
# 9112  1491004403              -240      female  4f70f8b4e4b03b7fba6a161b
# 9113  1491004693              -240        male  4dd9011c1838b8561d0e080e
#
#       VENUE LATITUDE  VENUE LONGITUDE    CITY COUNTRY  \
# 0          -3.104187       -60.011926  Manaus  Brazil
# 1          -3.101788       -60.017451  Manaus  Brazil
# 2          -3.108907       -60.019625  Manaus  Brazil
# 3          -3.088108       -60.062357  Manaus  Brazil
# 4          -3.104187       -60.011926  Manaus  Brazil
# 5          -3.124695       -60.008604    none  Brazil
# 6          -3.058496       -60.044966    none  Brazil
# 7          -3.105087       -60.010712  Manaus  Brazil
# 8          -3.130264       -60.023149  Manaus  Brazil
# 9          -3.078257       -60.010819  Manaus  Brazil
# 10         -3.000086       -59.990707  Manaus  Brazil
# 11         -3.106641       -60.033748  Manaus  Brazil
# 12         -3.063751       -60.057423  Manaus  Brazil
# 13         -3.085441       -60.025965  Manaus  Brazil
# 14         -3.107690       -60.038509  Manaus  Brazil
# 15         -3.065652       -60.011539  Manaus  Brazil
# 16         -3.111125       -60.007241    none  Brazil
# 17         -3.074036       -60.031542  Manaus  Brazil
# 18         -3.084998       -60.072558  Manaus  Brazil
# 19         -3.115191       -59.985483    none  Brazil
# 20         -3.089944       -60.020165    none  Brazil
# 21         -3.122725       -60.036923    none  Brazil
# 22         -3.105621       -60.033477  Manaus  Brazil
# 23         -3.115553       -59.997043    none  Brazil
# 24         -3.103290       -60.024997  Manaus  Brazil
# 25         -3.063914       -60.101478  Manaus  Brazil
# 26         -3.122000       -60.013094  Manaus  Brazil
# 27         -3.130264       -60.023149  Manaus  Brazil
# 28         -3.005597       -59.977979  Manaus  Brazil
# 29         -3.043967       -59.950810  Manaus  Brazil
# ...              ...              ...     ...     ...
# 9084       -3.124665       -60.043340  Manaus  Brazil
# 9085       -3.059296       -60.004068    none  Brazil
# 9086       -3.059283       -60.004035  Manaus  Brazil
# 9087       -3.092073       -59.962279  Manaus  Brazil
# 9088       -3.087370       -60.013108  Manaus  Brazil
# 9089       -3.097030       -60.025249  Manaus  Brazil
# 9090       -3.104134       -59.999269  Manaus  Brazil
# 9091       -3.126624       -60.007658    none  Brazil
# 9092       -3.134316       -59.978437  Manaus  Brazil
# 9093       -3.075736       -59.953062  Manaus  Brazil
# 9094       -3.116037       -59.989801  Manaus  Brazil
# 9095       -3.029272       -60.074423    none  Brazil
# 9096       -3.075584       -59.957060  Manaus  Brazil
# 9097       -3.095183       -60.026000  Manaus  Brazil
# 9098       -3.088076       -60.040627  Manaus  Brazil
# 9099       -3.109757       -59.975032  Manaus  Brazil
# 9100       -3.028030       -60.065241  Manaus  Brazil
# 9101       -3.097422       -60.023646  Manaus  Brazil
# 9102       -3.096960       -60.023441  Manaus  Brazil
# 9103       -3.092178       -59.962659    none  Brazil
# 9104       -3.044259       -59.958590  Manaus  Brazil
# 9105       -3.094205       -60.022686  Manaus  Brazil
# 9106       -3.088367       -60.018774  Manaus  Brazil
# 9107       -3.127033       -60.026211    none  Brazil
# 9108       -3.032323       -59.980510  Manaus  Brazil
# 9109       -3.083266       -60.028160  Manaus  Brazil
# 9110       -3.127157       -60.026889  Manaus  Brazil
# 9111       -3.039832       -59.958627  Manaus  Brazil
# 9112       -3.089585       -60.008604  Manaus  Brazil
# 9113       -3.122052       -60.014497  Manaus  Brazil
#
#        VENUE MACRO-CATEGORY ID    VENUE MACRO-CATEGORY NAME  \
# 0     4d4b7105d754a06378d81259               Shop & Service
# 1     4d4b7105d754a06374d81259                         Food
# 2     4d4b7105d754a06378d81259               Shop & Service
# 3     4d4b7105d754a06375d81259  Professional & Other Places
# 4     4d4b7105d754a06378d81259               Shop & Service
# 5     4e67e38e036454776db1fb3a                    Residence
# 6     4d4b7105d754a06374d81259                         Food
# 7     4d4b7105d754a06378d81259               Shop & Service
# 8     4d4b7104d754a06370d81259         Arts & Entertainment
# 9     4d4b7105d754a06374d81259                         Food
# 10    4d4b7105d754a06374d81259                         Food
# 11    4d4b7105d754a06374d81259                         Food
# 12    4d4b7105d754a06374d81259                         Food
# 13    4d4b7105d754a06374d81259                         Food
# 14    4d4b7105d754a06374d81259                         Food
# 15    4d4b7105d754a06374d81259                         Food
# 16    4d4b7105d754a06377d81259        Outdoors & Recreation
# 17    4d4b7105d754a06374d81259                         Food
# 18    4d4b7105d754a06378d81259               Shop & Service
# 19    4e67e38e036454776db1fb3a                    Residence
# 20    4e67e38e036454776db1fb3a                    Residence
# 21    4d4b7105d754a06374d81259                         Food
# 22    4d4b7105d754a06374d81259                         Food
# 23    4e67e38e036454776db1fb3a                    Residence
# 24    4d4b7105d754a06378d81259               Shop & Service
# 25    4d4b7105d754a06377d81259        Outdoors & Recreation
# 26    4d4b7105d754a06377d81259        Outdoors & Recreation
# 27    4d4b7104d754a06370d81259         Arts & Entertainment
# 28    4e67e38e036454776db1fb3a                    Residence
# 29    4e67e38e036454776db1fb3a                    Residence
# ...                        ...                          ...
# 9084  4d4b7105d754a06377d81259        Outdoors & Recreation
# 9085  4d4b7105d754a06375d81259  Professional & Other Places
# 9086  4d4b7105d754a06375d81259  Professional & Other Places
# 9087  4d4b7105d754a06372d81259         College & University
# 9088  4d4b7105d754a06375d81259  Professional & Other Places
# 9089  4d4b7105d754a06372d81259         College & University
# 9090  4d4b7105d754a06374d81259                         Food
# 9091  4d4b7105d754a06375d81259  Professional & Other Places
# 9092  4d4b7105d754a06375d81259  Professional & Other Places
# 9093  4d4b7105d754a06378d81259               Shop & Service
# 9094  4d4b7105d754a06374d81259                         Food
# 9095  4d4b7104d754a06370d81259         Arts & Entertainment
# 9096  4d4b7105d754a06378d81259               Shop & Service
# 9097  4d4b7105d754a06372d81259         College & University
# 9098  4d4b7105d754a06372d81259         College & University
# 9099  4d4b7105d754a06372d81259         College & University
# 9100  4d4b7105d754a06378d81259               Shop & Service
# 9101  4d4b7105d754a06378d81259               Shop & Service
# 9102  4d4b7105d754a06372d81259         College & University
# 9103  4d4b7105d754a06372d81259         College & University
# 9104  4d4b7105d754a06375d81259  Professional & Other Places
# 9105  4d4b7105d754a06378d81259               Shop & Service
# 9106  4d4b7105d754a06375d81259  Professional & Other Places
# 9107  4d4b7105d754a06376d81259               Nightlife Spot
# 9108  4d4b7105d754a06374d81259                         Food
# 9109  4d4b7104d754a06370d81259         Arts & Entertainment
# 9110  4d4b7105d754a06377d81259        Outdoors & Recreation
# 9111  4d4b7105d754a06374d81259                         Food
# 9112  4e67e38e036454776db1fb3a                    Residence
# 9113  4d4b7105d754a06375d81259  Professional & Other Places
#
#              VENUE CATEGORY ID           VENUE CATEGORY NAME  CHECK-INS COUNT  \
# 0     4bf58dd8d48988d1fd941735                 Shopping Mall           258789
# 1     4bf58dd8d48988d16c941735                  Burger Joint              439
# 2     4bf58dd8d48988d104951735                      Boutique               42
# 3     4bf58dd8d48988d132941735                        Church             6967
# 4     4bf58dd8d48988d1fd941735                 Shopping Mall           258789
# 5     4bf58dd8d48988d103941735                Home (private)              743
# 6     4bf58dd8d48988d1ca941735                   Pizza Place               52
# 7     52f2ab2ebcbc57f1066b8b42                 Big Box Store            15493
# 8     4bf58dd8d48988d137941735                       Theater            23260
# 9     5294c7523cf9994f4e043a62                    Acai House               12
# 10    4bf58dd8d48988d1ca941735                   Pizza Place               51
# 11    4bf58dd8d48988d1c7941735                   Snack Place             1500
# 12    4bf58dd8d48988d111941735           Japanese Restaurant               42
# 13    4bf58dd8d48988d1d2941735              Sushi Restaurant             1511
# 14    4bf58dd8d48988d1c7941735                   Snack Place              936
# 15    4bf58dd8d48988d1d0941735                  Dessert Shop              713
# 16    4bf58dd8d48988d164941735                         Plaza             1613
# 17    4bf58dd8d48988d1d2941735              Sushi Restaurant             2655
# 18    4bf58dd8d48988d1fd941735                 Shopping Mall            51337
# 19    4bf58dd8d48988d103941735                Home (private)             1137
# 20    4bf58dd8d48988d103941735                Home (private)             1022
# 21    4bf58dd8d48988d1ca941735                   Pizza Place              641
# 22    4bf58dd8d48988d1df931735                     BBQ Joint              253
# 23    4bf58dd8d48988d103941735                Home (private)             1078
# 24    52f2ab2ebcbc57f1066b8b42                 Big Box Store             7203
# 25    4bf58dd8d48988d1e2941735                         Beach            20616
# 26    4f2a25ac4b909258e854f55f                  Neighborhood            16588
# 27    4bf58dd8d48988d137941735                       Theater            23260
# 28    4f2a210c4b9023bd5841ed28           Housing Development             7804
# 29    4bf58dd8d48988d103941735                Home (private)               32
# ...                        ...                           ...              ...
# 9084  4bf58dd8d48988d1e0941735               Harbor / Marina             1918
# 9085  4bf58dd8d48988d129941735                     City Hall              181
# 9086  4bf58dd8d48988d126941735           Government Building             1931
# 9087  4bf58dd8d48988d1ae941735                    University            13240
# 9088  4d4b7105d754a06375d81259   Professional & Other Places              256
# 9089  4bf58dd8d48988d1a8941735  General College & University            47264
# 9090  4bf58dd8d48988d1c4941735                    Restaurant              165
# 9091  4bf58dd8d48988d178941735              Dentist's Office               26
# 9092  4bf58dd8d48988d124941735                        Office             8216
# 9093  4bf58dd8d48988d113951735                   Gas Station              696
# 9094  4bf58dd8d48988d1ca941735                   Pizza Place              471
# 9095  4bf58dd8d48988d193941735                    Water Park               50
# 9096  4bf58dd8d48988d1fd941735                 Shopping Mall            13563
# 9097  4bf58dd8d48988d198941735     College Academic Building            15007
# 9098  4bf58dd8d48988d1ae941735                    University             5391
# 9099  4bf58dd8d48988d1ae941735                    University             9547
# 9100  52f2ab2ebcbc57f1066b8b42                 Big Box Store             1181
# 9101  4bf58dd8d48988d1fd941735                 Shopping Mall            49704
# 9102  4bf58dd8d48988d1a8941735  General College & University             4053
# 9103  4bf58dd8d48988d1af941735            College Auditorium              326
# 9104  4e52adeebd41615f56317744                 Military Base              213
# 9105  4bf58dd8d48988d1fd941735                 Shopping Mall           156660
# 9106  50328a8e91d4c4b30a586d6c                    Non-Profit               23
# 9107  4bf58dd8d48988d1d5941735                     Hotel Bar              638
# 9108  4bf58dd8d48988d16c941735                  Burger Joint               58
# 9109  4bf58dd8d48988d188941735                Soccer Stadium            17723
# 9110  4bf58dd8d48988d175941735          Gym / Fitness Center             7211
# 9111  4bf58dd8d48988d16a941735                        Bakery              516
# 9112  4bf58dd8d48988d103941735                Home (private)              494
# 9113  4bf58dd8d48988d132941735                        Church             1461
#
#      VENUE LIKES VENUE RATING
# 0           4111          9.0
# 1             31          7.3
# 2              1         none
# 3             95         none
# 4           4111          9.0
# 5              0         none
# 6              2         none
# 7            309          6.0
# 8           1289          9.5
# 9              0         none
# 10             0         none
# 11            59          5.8
# 12             3         none
# 13           103          8.1
# 14            52          8.5
# 15            42          7.1
# 16             6          6.2
# 17           102          8.2
# 18          1845          8.5
# 19             1         none
# 20             2         none
# 21            24          7.4
# 22             7          6.3
# 23             2         none
# 24           382          9.1
# 25           682          9.0
# 26            86         none
# 27          1289          9.5
# 28            52         none
# 29             0         none
# ...          ...          ...
# 9084          37         none
# 9085           0         none
# 9086          15         none
# 9087          43         none
# 9088           5         none
# 9089         197         none
# 9090           6          6.9
# 9091           1         none
# 9092          22         none
# 9093           7          6.4
# 9094          12          7.2
# 9095           1         none
# 9096         266          6.3
# 9097          63         none
# 9098          26         none
# 9099          37         none
# 9100          77          7.8
# 9101        1031          7.1
# 9102          24         none
# 9103           3         none
# 9104           0         none
# 9105        2768          8.4
# 9106           0         none
# 9107           4         none
# 9108           0         none
# 9109        1046          9.2
# 9110          77          7.9
# 9111           2         none
# 9112           1         none
# 9113          17         none
#
# [45955 rows x 15 columns]

# %% [markdown]
# ## Quantos check-ins?

# %%
qtd_checkins_2015 = len(mao_2015_df)
qtd_checkins_2016 = len(mao_2016_df)
qtd_checkins_2017 = len(mao_2017_df)
qtd_checkins_total = len(mao_df)

# %%
print("2015: ", qtd_checkins_2015,
     "\n2016: ", qtd_checkins_2016,
     "\n2017: ", qtd_checkins_2017,
     "\nTotal: ", qtd_checkins_total)
# Out:
# 2015:  20857
# 2016:  15984
# 2017:  9114
# Total:  45955

# %% [markdown]
# ### Gráfico Check-ins x Ano

# %%
qtd_checkins = [qtd_checkins_2015, qtd_checkins_2016, qtd_checkins_2017]
anos = ["2015", "2016", "2017"]

# %%
plt.bar(anos, qtd_checkins)
plt.xlabel("Anos")
plt.ylabel("# check-ins")
plt.title("Check-ins por ano")
plt.show()

# %% [markdown]
# ## Quantos locais existem nestes check-ins?

# %%
#sao salvas nas variaveis todos os valores presentes na coluna "VENUE ID", 
#considerando apenas uma ocorrencia de cada valor
venues_2015 = mao_2015_df["VENUE ID"].unique()
venues_2016 = mao_2016_df["VENUE ID"].unique()
venues_2017 = mao_2017_df["VENUE ID"].unique()
venues_total = mao_df["VENUE ID"].unique()

# %%
print("2015: ", len(venues_2015),
      "\n2016: ", len(venues_2016),
      "\n2017: ", len(venues_2017), 
      "\nTotal: ", len(venues_total))
# Out:
# 2015:  4859
# 2016:  4249
# 2017:  3055
# Total:  9027

# %% [markdown]
# ### Gráfico Locais Distintos x Ano

# %%
venues = [len(venues_2015), len(venues_2016), len(venues_2017)]
anos = ["2015", "2016", "2017"]

# %%
plt.bar(anos, venues)
plt.xlabel("Anos")
plt.ylabel("# locais")
plt.title("Locais distintos por ano")
plt.show()

# %% [markdown]
# ## Como estão distribuídos estes check-ins pela cidade?
# ### Heatmap de check-ins distribuídos pelo mapa da cidade

# %%
gmap = gmplot.GoogleMapPlotter(-3.044662, -59.967104, 12)#inicializacao do mapa
                                                         #parametros = lat, long, zoom

# %%
lats_total = mao_df["VENUE LATITUDE"]  #Latitudes 
long_total = mao_df["VENUE LONGITUDE"] #Longitudes
gmap.heatmap(lats_total, long_total)   #Adicionando pontos de check-ins na cidade
gmap.draw("Data/heatmap_total.html")   #Gerando Arquivo html com o heatmap de check-ins da cidade de manaus

# %% [markdown]
# ## De que categorias são esses check-ins?

# %%
categories_total = pd.value_counts(mao_df["VENUE MACRO-CATEGORY NAME"], sort=True)

# %%
categories_total
# Out:
# Residence                      10158
# Professional & Other Places     8439
# College & University            6334
# Food                            5769
# Shop & Service                  5703
# Outdoors & Recreation           4149
# Travel & Transport              2385
# Arts & Entertainment            1508
# Nightlife Spot                  1448
# Event                             62
# Name: VENUE MACRO-CATEGORY NAME, dtype: int64

# %% [markdown]
# ### Gráfico Check-ins x Categoria

# %%
plt.bar(categories_total.keys(), categories_total)
plt.xticks(rotation=90)
plt.xlabel("Categorias")
plt.ylabel("# Check-ins")
plt.title("Check-ins por Categoria")
plt.show()

# %% [markdown]
# ## E quais são as subcategorias?

# %%
subcat_total = pd.value_counts(mao_df["VENUE CATEGORY NAME"], sort=True).head(10)
subcat_total
# Out:
# Home (private)                              6483
# University                                  2748
# Residential Building (Apartment / Condo)    2340
# Shopping Mall                               1984
# Neighborhood                                1402
# Housing Development                         1313
# Road                                        1199
# Office                                      1027
# General College & University                 946
# College Academic Building                    903
# Name: VENUE CATEGORY NAME, dtype: int64

# %% [markdown]
# ## Quais são os locais mais bem avaliados da cidade?

# %%
mao_df_new = mao_df.loc[mao_df["VENUE RATING"]!="none"] #cria-se um novo dataframe limpando as linhas de VENUE RATING que possui "none"
mao_df_new = mao_df_new.sort_values("VENUE RATING", ascending = False)

# %%
mao_ranking = mao_df_new.drop_duplicates("VENUE ID")

# %%
mao_ranking.head(5)
# Out:
#        CREATED AT  TIME ZONE OFFSET USER GENDER                  VENUE ID  \
# 6695   1457827778              -240      female  4bb7be58314e95211ca2479d
# 5496   1457644178              -240        male  4b62c956f964a520a7522ae3
# 6988   1457897636              -240        male  4b6b5677f964a520d9012ce3
# 16311  1427238328              -240      female  4dcf0a267d8b975f18deea9f
# 8234   1490748272              -240      female  4bc5fd01db8fa593538d9b37
#
#        VENUE LATITUDE  VENUE LONGITUDE    CITY COUNTRY  \
# 6695        -3.130264       -60.023149  Manaus  Brazil
# 5496        -3.130686       -60.022839  Manaus  Brazil
# 6988        -3.104127       -60.011834  Manaus  Brazil
# 16311       -3.135920       -60.016656  Manaus  Brazil
# 8234        -3.074090       -60.031089  Manaus  Brazil
#
#         VENUE MACRO-CATEGORY ID VENUE MACRO-CATEGORY NAME  \
# 6695   4d4b7104d754a06370d81259      Arts & Entertainment
# 5496   4d4b7105d754a06377d81259     Outdoors & Recreation
# 6988   4d4b7105d754a06378d81259            Shop & Service
# 16311  4d4b7105d754a06377d81259     Outdoors & Recreation
# 8234   4d4b7105d754a06374d81259                      Food
#
#               VENUE CATEGORY ID VENUE CATEGORY NAME  CHECK-INS COUNT  \
# 6695   4bf58dd8d48988d137941735             Theater            23166
# 5496   4bf58dd8d48988d164941735               Plaza            38812
# 6988   4bf58dd8d48988d114951735           Bookstore            21686
# 16311  4bf58dd8d48988d163941735                Park             9289
# 8234   4bf58dd8d48988d1df931735           BBQ Joint            12743
#
#       VENUE LIKES VENUE RATING
# 6695         1282          9.6
# 5496          688          9.5
# 6988          908          9.4
# 16311         183          9.3
# 8234          703          9.3

# %%
#Expandir a largura da coluna para possibilitar a visualizacao do link
pd.set_option('display.max_colwidth', 100)

# %%
#Adicionando o link do Lugar no atributo VENUE_ID
mao_ranking["VENUE ID"] = "https://pt.foursquare.com/v/" + mao_ranking["VENUE ID"].astype(str)
# Out:
# /Users/jeanlima/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mao_ranking.head(10)
# Out:
#        CREATED AT  TIME ZONE OFFSET USER GENDER  \
# 6695   1457827778              -240      female
# 5496   1457644178              -240        male
# 6988   1457897636              -240        male
# 16311  1427238328              -240      female
# 8234   1490748272              -240      female
# 6500   1457802109              -240        male
# 6811   1490312120              -240        male
# 4958   1425791668              -240      female
# 14712  1426995733              -240      female
# 9861   1426415665              -240      female
#
#                                                    VENUE ID  VENUE LATITUDE  \
# 6695   https://pt.foursquare.com/v/4bb7be58314e95211ca2479d       -3.130264
# 5496   https://pt.foursquare.com/v/4b62c956f964a520a7522ae3       -3.130686
# 6988   https://pt.foursquare.com/v/4b6b5677f964a520d9012ce3       -3.104127
# 16311  https://pt.foursquare.com/v/4dcf0a267d8b975f18deea9f       -3.135920
# 8234   https://pt.foursquare.com/v/4bc5fd01db8fa593538d9b37       -3.074090
# 6500   https://pt.foursquare.com/v/4b816a36f964a520bea430e3       -3.112166
# 6811   https://pt.foursquare.com/v/4da8990f5da3ef8bf16235f4       -3.107652
# 4958   https://pt.foursquare.com/v/52faa201498e51f9d0c8fe8b       -3.066115
# 14712  https://pt.foursquare.com/v/4ba938faf964a520da153ae3       -3.099630
# 9861   https://pt.foursquare.com/v/4e74f5cf45ddd4323f862b3a       -3.083266
#
#        VENUE LONGITUDE    CITY COUNTRY   VENUE MACRO-CATEGORY ID  \
# 6695        -60.023149  Manaus  Brazil  4d4b7104d754a06370d81259
# 5496        -60.022839  Manaus  Brazil  4d4b7105d754a06377d81259
# 6988        -60.011834  Manaus  Brazil  4d4b7105d754a06378d81259
# 16311       -60.016656  Manaus  Brazil  4d4b7105d754a06377d81259
# 8234        -60.031089  Manaus  Brazil  4d4b7105d754a06374d81259
# 6500        -60.016682  Manaus  Brazil  4d4b7105d754a06374d81259
# 6811        -60.020675  Manaus  Brazil  4d4b7105d754a06378d81259
# 4958        -60.098100  Manaus  Brazil  4d4b7105d754a06377d81259
# 14712       -60.015138  Manaus  Brazil  4d4b7105d754a06374d81259
# 9861        -60.028160  Manaus  Brazil  4d4b7104d754a06370d81259
#
#       VENUE MACRO-CATEGORY NAME         VENUE CATEGORY ID  \
# 6695       Arts & Entertainment  4bf58dd8d48988d137941735
# 5496      Outdoors & Recreation  4bf58dd8d48988d164941735
# 6988             Shop & Service  4bf58dd8d48988d114951735
# 16311     Outdoors & Recreation  4bf58dd8d48988d163941735
# 8234                       Food  4bf58dd8d48988d1df931735
# 6500                       Food  4bf58dd8d48988d16b941735
# 6811             Shop & Service  4bf58dd8d48988d110951735
# 4958      Outdoors & Recreation  4bf58dd8d48988d164941735
# 14712                      Food  4bf58dd8d48988d16c941735
# 9861       Arts & Entertainment  4bf58dd8d48988d188941735
#
#         VENUE CATEGORY NAME  CHECK-INS COUNT VENUE LIKES VENUE RATING
# 6695                Theater            23166        1282          9.6
# 5496                  Plaza            38812         688          9.5
# 6988              Bookstore            21686         908          9.4
# 16311                  Park             9289         183          9.3
# 8234              BBQ Joint            12743         703          9.3
# 6500   Brazilian Restaurant             6758         602          9.3
# 6811     Salon / Barbershop             2112          64          9.3
# 4958                  Plaza             5855         171          9.2
# 14712          Burger Joint             9148         533          9.2
# 9861         Soccer Stadium            18279        1049          9.2

# %% [markdown]
# ## Quais são os lugares mais frequentados?

# %%
mao_ranking.sort_values("CHECK-INS COUNT", ascending=False).head(10)
# Out:
#        CREATED AT  TIME ZONE OFFSET USER GENDER  \
# 1201   1488744621              -240      female
# 1503   1488828595              -240      female
# 1596   1425390372              -240      female
# 2074   1457106929              -240        male
# 10121  1426458048              -240      female
# 7638   1457997462              -240        male
# 5496   1457644178              -240        male
# 11245  1458605554              -240        male
# 12353  1458790190              -240        male
# 13940  1459131858              -240        male
#
#                                                    VENUE ID  VENUE LATITUDE  \
# 1201   https://pt.foursquare.com/v/4b535772f964a520249827e3       -3.104079
# 1503   https://pt.foursquare.com/v/4b5d08a1f964a520c64f29e3       -3.031961
# 1596   https://pt.foursquare.com/v/4b983bf7f964a520213635e3       -3.094191
# 2074   https://pt.foursquare.com/v/4b885e75f964a520aef231e3       -3.101026
# 10121  https://pt.foursquare.com/v/4ea4f8e98b81a02f8aa555d2       -3.084998
# 7638   https://pt.foursquare.com/v/4b4778e2f964a520273326e3       -3.097422
# 5496   https://pt.foursquare.com/v/4b62c956f964a520a7522ae3       -3.130686
# 11245  https://pt.foursquare.com/v/4b5a3fd4f964a52069b728e3       -3.125029
# 12353  https://pt.foursquare.com/v/4c81cad12f1c236a9ec63343       -3.095098
# 13940  https://pt.foursquare.com/v/4ba368bdf964a520c53a38e3       -3.108067
#
#        VENUE LONGITUDE    CITY COUNTRY   VENUE MACRO-CATEGORY ID  \
# 1201        -60.011790  Manaus  Brazil  4d4b7105d754a06378d81259
# 1503        -60.046039  Manaus  Brazil  4d4b7105d754a06379d81259
# 1596        -60.023019  Manaus  Brazil  4d4b7105d754a06378d81259
# 2074        -60.025170  Manaus  Brazil  4d4b7105d754a06378d81259
# 10121       -60.072558  Manaus  Brazil  4d4b7105d754a06378d81259
# 7638        -60.023646  Manaus  Brazil  4d4b7105d754a06378d81259
# 5496        -60.022839  Manaus  Brazil  4d4b7105d754a06377d81259
# 11245       -59.983454  Manaus  Brazil  4d4b7105d754a06378d81259
# 12353       -60.051132  Manaus  Brazil  4d4b7104d754a06370d81259
# 13940       -60.023601  Manaus  Brazil  4d4b7105d754a06374d81259
#
#       VENUE MACRO-CATEGORY NAME         VENUE CATEGORY ID  \
# 1201             Shop & Service  4bf58dd8d48988d1fd941735
# 1503         Travel & Transport  4bf58dd8d48988d1ed931735
# 1596             Shop & Service  4bf58dd8d48988d1fd941735
# 2074             Shop & Service  4bf58dd8d48988d1fd941735
# 10121            Shop & Service  4bf58dd8d48988d1fd941735
# 7638             Shop & Service  4bf58dd8d48988d1fd941735
# 5496      Outdoors & Recreation  4bf58dd8d48988d164941735
# 11245            Shop & Service  4bf58dd8d48988d1fd941735
# 12353      Arts & Entertainment  4bf58dd8d48988d1e9931735
# 13940                      Food  4bf58dd8d48988d16e941735
#
#         VENUE CATEGORY NAME  CHECK-INS COUNT VENUE LIKES VENUE RATING
# 1201          Shopping Mall           257161        4085          9.0
# 1503                Airport           180908        1539          6.7
# 1596          Shopping Mall           157927        2781          8.4
# 2074          Shopping Mall            70388        1415          8.0
# 10121         Shopping Mall            51341        1845          8.5
# 7638          Shopping Mall            49887        1035          7.1
# 5496                  Plaza            38812         688          9.5
# 11245         Shopping Mall            37202         809          7.7
# 12353             Rock Club            29449        1325          9.1
# 13940  Fast Food Restaurant            26506         783          8.2
